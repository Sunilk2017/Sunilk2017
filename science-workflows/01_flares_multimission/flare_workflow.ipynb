# %% [markdown]
# # Flare hands on tutorial
#
# The hands-on sessions are designed to be informal and interactive.
#
# Prticipants will work directly with the data, with the team leads available for questions, support, and discussion.
#
# People can engage at different depths depending on their background and interest:
# - some participants may explore a dataset in more detail and try extended analysis
# - others may focus on getting started and understanding the core tools and workflows
#
#
#
#
# ## Flare: 2025-01-19 03:30 UT
# For this flare session, we will analyse an M-class solar flare from 19-Jan-2025 at ~ 03:30.
# This flare was observed by both Aditya-L1 andd Solar Orbiter. We will analyse this flare using
# - Solar Orbiter/STIX
# - Solar Orbiter/EUI
# - Aditya-L1/HEL1OS
# - Aditya-L1/SoLEXS
# - Aditya-L1/SUIT
#
# This notebook is just a starting point! Please run with it. We've set some tasks to do!
#
# ![img](https://github.com/ISRO-ESA-Heliophysics-Workshop/hands-on-materials/blob/main/science-workflows/01_flares_multimission/overview_flare.jpeg?raw=1)
#
# Note that this notebook also includes downloading the data - but also requires some locally. All the data in this notebook is available here: https://drive.google.com/drive/u/1/folders/1czUWf8y9TWfrYXVf4jA52ZFB8LzUaHlp
#
# ## Use what you've seen in the tutorial sessions:
# https://github.com/ISRO-ESA-Heliophysics-Workshop/hands-on-materials/
#
#
# ## This is just a starting notebook. Here are some tasks and some things to try:
# - Plot the locations of the spacecraft (e.g. Earth and Solar Orbiter)
#
# Timeseries:
# - Plot the quicklook lightcurves of STIX
# - Find the time delay between the STIX and Earth observations
# - Plot the SolEXS lightcurves and the HEL1Os lightcurves
#
# Imaging Observations:
# - Search for EUI data (or download from the google drive) and plot the image as a sunpy map.
# - Plot the EUI image and make a submap over the region of interest.
# - Plot the SUIT images (of the decay phase, SUIT missed the start of this flare)
# - Create a STIX image using STIXpy

# %%
# uncomment below if using google colab
## !pip -q install -r https://raw.githubusercontent.com/ISRO-ESA-Heliophysics-Workshop/hands-on-materials/refs/heads/main/science-workflows/01_flares_multimission/requirements.txt

# %%
# !pip install stixpy
# Out:
# Collecting stixpy
#   Downloading stixpy-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: sunpy>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (7.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from stixpy) (25.0)
# Collecting reproject (from stixpy)
#   Downloading reproject-0.19.0-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting astroquery (from stixpy)
#   Downloading astroquery-0.4.11-py3-none-any.whl.metadata (6.5 kB)
# Collecting intervaltree (from stixpy)
#   Downloading intervaltree-3.2.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting roentgen (from stixpy)
#   Downloading roentgen-2.4.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stixpy) (3.10.0)
# Collecting xrayvisim~=0.2.0rc (from stixpy)
#   Downloading xrayvisim-0.2.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: astropy>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (7.2.0)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2025.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.0.2)
# Requirement already satisfied: parfive>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.2.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.0.1.5)
# Requirement already satisfied: requests>=2.32.1 in /usr/local/lib/python3.12/dist-packages (from sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.32.4)
# Requirement already satisfied: contourpy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.3.3)
# Requirement already satisfied: mpl-animators>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.2.4)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.16.3)
# Requirement already satisfied: beautifulsoup4>=4.13.1 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (4.13.5)
# Requirement already satisfied: drms>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.66.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (4.67.1)
# Requirement already satisfied: zeep>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (4.3.2)
# Collecting cdflib>=1.3.2 (from sunpy[map,net,timeseries]>=6.0.0->stixpy)
#   Downloading cdflib-1.3.8-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: h5netcdf>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.8.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (3.15.1)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.2.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stixpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stixpy) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stixpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stixpy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stixpy) (3.3.1)
# Collecting astropy-healpix>=1.0 (from reproject->stixpy)
#   Downloading astropy_healpix-1.1.3-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: dask>=2024.4.1 in /usr/local/lib/python3.12/dist-packages (from dask[array]>=2024.4.1->reproject->stixpy) (2025.12.0)
# Collecting dask-image>=2025.11.0 (from reproject->stixpy)
#   Downloading dask_image-2025.11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting zarr>=2.17.0 (from reproject->stixpy)
#   Downloading zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Collecting pyavm>=0.9.6 (from reproject->stixpy)
#   Downloading pyavm-0.9.8-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xarray>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from xrayvisim~=0.2.0rc->stixpy) (2025.12.0)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.12/dist-packages (from astroquery->stixpy) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/local/lib/python3.12/dist-packages (from astroquery->stixpy) (25.7.0)
# Collecting pyvo>=1.5 (from astroquery->stixpy)
#   Downloading pyvo-1.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting sortedcontainers (from intervaltree->stixpy)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (0.2026.1.12.0.42.13)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (6.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.13.1->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.13.1->sunpy[map,net,timeseries]>=6.0.0->stixpy) (4.15.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject->stixpy) (8.3.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject->stixpy) (3.1.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject->stixpy) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask>=2024.4.1->dask[array]>=2024.4.1->reproject->stixpy) (0.12.1)
# Collecting pims>=0.4.1 (from dask-image>=2025.11.0->reproject->stixpy)
#   Downloading pims-0.7.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tifffile>=2018.10.18 in /usr/local/lib/python3.12/dist-packages (from dask-image>=2025.11.0->reproject->stixpy) (2026.1.14)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib>=0.999->astroquery->stixpy) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib>=0.999->astroquery->stixpy) (0.5.1)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery->stixpy) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery->stixpy) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery->stixpy) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery->stixpy) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery->stixpy) (6.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2025.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (3.13.3)
# Requirement already satisfied: aioftp>=0.17.1 in /usr/local/lib/python3.12/dist-packages (from parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (0.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.1->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2026.1.4)
# Collecting donfig>=0.8 (from zarr>=2.17.0->reproject->stixpy)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr>=2.17.0->reproject->stixpy) (1.8.0)
# Collecting numcodecs>=0.14 (from zarr>=2.17.0->reproject->stixpy)
#   Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: attrs>=17.2.0 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (25.4.0)
# Requirement already satisfied: isodate>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (0.7.2)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (6.0.2)
# Requirement already satisfied: platformdirs>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (4.5.1)
# Requirement already satisfied: requests-toolbelt>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.0.0)
# Requirement already satisfied: requests-file>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from zeep>=4.3.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (3.0.1)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.12/dist-packages (from dask[array,dataframe]>=2024.4.1->dask-image>=2025.11.0->reproject->stixpy) (18.1.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask>=2024.4.1->dask[array]>=2024.4.1->reproject->stixpy) (1.0.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from pims>=0.4.1->dask-image>=2025.11.0->reproject->stixpy) (2.37.2)
# Collecting slicerator>=0.9.8 (from pims>=0.4.1->dask-image>=2025.11.0->reproject->stixpy)
#   Downloading slicerator-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=15.0->astroquery->stixpy) (43.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->parfive>=2.1.0->parfive[ftp]>=2.1.0->sunpy>=6.0.0->sunpy[map,net,timeseries]>=6.0.0->stixpy) (1.22.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=15.0->astroquery->stixpy) (10.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery->stixpy) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery->stixpy) (2.23)
# Downloading stixpy-0.2.0-py3-none-any.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.1/959.1 kB 30.0 MB/s eta 0:00:00
# Downloading reproject-0.19.0-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.4 MB/s eta 0:00:00
# Downloading xrayvisim-0.2.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 3.2 MB/s eta 0:00:00
# Downloading astroquery-0.4.11-py3-none-any.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 99.3 MB/s eta 0:00:00
# Downloading intervaltree-3.2.1-py2.py3-none-any.whl (25 kB)
# Downloading roentgen-2.4.0-py3-none-any.whl (412 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 25.4 MB/s eta 0:00:00
# Downloading astropy_healpix-1.1.3-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (191 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.0/191.0 kB 14.6 MB/s eta 0:00:00
# Downloading cdflib-1.3.8-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.7/79.7 kB 6.4 MB/s eta 0:00:00
# Downloading dask_image-2025.11.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 4.9 MB/s eta 0:00:00
# Downloading pyavm-0.9.8-py3-none-any.whl (378 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.8/378.8 kB 26.1 MB/s eta 0:00:00
# Downloading pyvo-1.8-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.9 MB/s eta 0:00:00
# Downloading zarr-3.1.5-py3-none-any.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 18.3 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 81.2 MB/s eta 0:00:00
# Downloading slicerator-1.1.0-py3-none-any.whl (10 kB)
# Building wheels for collected packages: pims
#   Building wheel for pims (setup.py) ... done
#   Created wheel for pims: filename=PIMS-0.7-py3-none-any.whl size=84590 sha256=80f4c41d7ebf6f9bd4782ab7076be3d241a4eed453f16918c23cade1c12a5cd4
#   Stored in directory: /root/.cache/pip/wheels/be/9c/72/7cb84823aaa980c2e44064caae0ba869239270fac14f7129aa
# Successfully built pims
# Installing collected packages: sortedcontainers, slicerator, pyavm, numcodecs, intervaltree, donfig, cdflib, zarr, pims, roentgen, pyvo, astropy-healpix, xrayvisim, dask-image, astroquery, reproject, stixpy
# Successfully installed astropy-healpix-1.1.3 astroquery-0.4.11 cdflib-1.3.8 dask-image-2025.11.0 donfig-0.8.1.post1 intervaltree-3.2.1 numcodecs-0.16.5 pims-0.7 pyavm-0.9.8 pyvo-1.8 reproject-0.19.0 roentgen-2.4.0 slicerator-1.1.0 sortedcontainers-2.4.0 stixpy-0.2.0 xrayvisim-0.2.1 zarr-3.1.5

# %%
import sunpy_soar
from sunpy.net import Fido, attrs as a
import matplotlib.pyplot as plt
from astropy import units as u

from sunpy import timeseries as ts
from stixpy import timeseries
import stixpy.net
import sunpy.map
from astropy.coordinates import SkyCoord
import glob
import pandas as pd

# %% [markdown]
# # 1.  Lets start by plotting the flare  as observed by GOES/XRS

# %%
tstart = "2025-01-19 03:20"
tend = "2025-01-19 04:00"

# %% [markdown]
# Lets start by searching for the GOES/XRS data using Fido.

# %%
res = Fido.search(a.Time(tstart, tend),
                  a.Instrument.xrs,
                  a.Resolution.flx1s,
                  a.goes.SatelliteNumber(16))

# %% [markdown]
# Lets download this data into the current directory

# %%
Fido.fetch(res, path="./")
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# sci_xrsf-l2-flx1s_g16_d20250119_v2-2-0.nc:   0%|          | 0.00/5.01M [00:00<?, ?B/s]
# <parfive.results.Results object at 0x783dfb643dd0>
# ['sci_xrsf-l2-flx1s_g16_d20250119_v2-2-0.nc']

# %% [markdown]
# Now we have this data, lets read it into a sunpy timeseries and plot!

# %%
goes_ts = ts.TimeSeries('sci_xrsf-l2-flx1s_g16_d20250119_v2-2-0.nc')
goes_ts.plot()
# Out:
# <Axes: ylabel='Watts m$^{-2}$'>

# %% [markdown]
# lets now zoom in and crop for the region of interest:

# %%
goes_flare = goes_ts.truncate(tstart, tend)
goes_flare.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2158885823.py in <cell line: 0>()
# ----> 1 goes_flare = goes_ts.truncate(tstart, tend)
#       2 goes_flare.plot()
#
# NameError: name 'goes_ts' is not defined

# %% [markdown]
# ## 2. TASK: Now we want to check where Solar Orbiter was with respect to each, lets plot the positions of the spacecraft!

# %% [markdown]
# ## 3. Lets get some STIX data!

# %%
stix_res = Fido.search(a.Time("2025-01-19", "2025-01-19 23:00"),
                       a.Instrument.stix, a.soar.Product.stix_ql_lightcurve)
Fido.fetch(stix_res, path="./")

# %%
stix_ts = ts.TimeSeries('solo_L1_stix-ql-lightcurve_20250119_V02.fits')
stix_ts.plot()

# %%
stix_flare = stix_ts.truncate(tstart, tend)

# %%
stix_flare.plot()

# %%
solo_earth_timedelay = stix_flare.meta.metas[0]["EAR_TDEL"]

# %%
solo_earth_timedelay

# %% [markdown]
# ## Search for some EUI data

# %%
res = Fido.search(a.Time(tstart, tend),
                  a.soar.Product.eui_fsi304_image, a.Level(2), a.Provider.soar)

# %%
Fido.fetch(res, path="./")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2071197042.py in <cell line: 0>()
# ----> 1 Fido.fetch(res, path="./")
#
# NameError: name 'Fido' is not defined

# %% [markdown]
# ## TASK : make an EUI map and make a submap over the region of interest
